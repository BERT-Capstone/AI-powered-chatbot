# %% [markdown]
# ## Brief Description

# %% [markdown]
# <a id='Introduction'></a>
#
# The datasets for cleaning were obtained from [the Global Knowledge Partnership on Migration and Development (KNOMAD)](https://www.knomad.org/data/remittances) website in their broader effort to fill the knowledge gaps for monitoring and analyzing migration and remittances. It provides remittance data movements (inbound and outbound) between various countries.
#
# Summary Content:
# The datasets were cleaned and saved as CSV files.
#
# * Time period: 2000 till 2022
# * This dataset contains two files:
#     * `remittance-inflows_clean.csv` - Historical remittance money inflow into world countries since 2000.
#     * `remittance-outflows_clean.csv` - Historical remittance money outflow from world countries since 2000.
#
# All monetary values are in terms of millions of US dollars.
#
# Each dataset contains the names of countries in the rows, with remittance values listed in the columns. The final column represents the percentage of Gross Domestic Product (GDP) that the remittance value made up in 2022.

# %% [markdown]
# ##  Data Cleaning for Remittance Inflow

# %%
# Importing libraries
import numpy as np
import pandas as pd
import warnings

# %% [markdown]
# #### Preparing datasets

# %%
# Load the inward remittance flows dataset
inward_filepath = '/content/inward_remittance_flows_december_2023_1.xlsx'
#'https://knomad.org/sites/default/files/2023-12/inward_remittance_flows_december_2023_1.xlsx'
df = pd.read_excel(inward_filepath, index_col=0)
print(df.shape)
# Display the first few rows of the dataset
df.head(10)
# Out:
# (226, 25)
#                                         2000        2001        2002  \
# Remittance inflows (US$ million)
# Afghanistan                         0.000000    0.000000    0.000000
# Albania                           597.800000  699.300000  733.570000
# Algeria                             0.000000    0.000000    0.000000
# American Samoa                           NaN         NaN         NaN
# Andorra                             0.000000    0.000000    0.000000
# Angola                              0.000000    0.000000    0.000000
# Antigua and Barbuda                17.342963   23.676667   14.242167
# Argentina                          86.343659  189.600000  206.630000
# Armenia                           182.160000  209.240000  263.890000
# Aruba                               1.083799    1.335196    1.329609
#
#                                         2003         2004         2005  \
# Remittance inflows (US$ million)
# Afghanistan                         0.000000     0.000000     0.000000
# Albania                           888.748582  1160.672105  1289.704316
# Algeria                             0.000000     0.000000   170.000000
# American Samoa                           NaN          NaN          NaN
# Andorra                             0.000000     0.000000     0.000000
# Angola                              0.000000     0.000000     0.000000
# Antigua and Barbuda                16.372237    17.601626    18.305489
# Argentina                         273.420000   311.780000   432.090000
# Armenia                           335.860000   787.519510   915.231162
# Aruba                               0.273743     1.458101     0.819846
#
#                                          2006         2007         2008  \
# Remittance inflows (US$ million)
# Afghanistan                          0.000000     0.000000    89.500000
# Albania                           1359.467325  1468.020000  1865.600000
# Algeria                            189.000000    99.004563   103.631887
# American Samoa                            NaN          NaN          NaN
# Andorra                              0.000000     0.000000     0.000000
# Angola                               0.000000     0.000000    82.084000
# Antigua and Barbuda                 19.325720    20.783287    21.828403
# Argentina                          540.700000   606.498927   705.144403
# Armenia                           1169.173063  1644.375091  1904.067123
# Aruba                                1.036166     5.195531     6.759777
#
#                                          2009  ...         2015         2016  \
# Remittance inflows (US$ million)               ...
# Afghanistan                        140.695166  ...   348.624717   627.710802
# Albania                           1717.698012  ...  1290.863508  1306.009167
# Algeria                            150.336961  ...  1997.393458  1989.023597
# American Samoa                            NaN  ...          NaN          NaN
# Andorra                              0.000000  ...     0.000000     0.000000
# Angola                               0.200000  ...    11.114712     3.988048
# Antigua and Barbuda                 20.658719  ...    31.244412    26.705676
# Argentina                          628.542376  ...   494.433532   391.579048
# Armenia                           1439.809232  ...  1491.475903  1382.330887
# Aruba                                9.050279  ...    53.640101    52.700000
#
#                                          2017         2018         2019  \
# Remittance inflows (US$ million)
# Afghanistan                        822.731630   803.546454   828.571904
# Albania                           1311.822432  1458.210056  1472.812242
# Algeria                           1791.887073  1984.998399  1785.838683
# American Samoa                            NaN          NaN          NaN
# Andorra                              0.000000     0.000000    21.100000
# Angola                               1.418196     1.579247     3.445473
# Antigua and Barbuda                 24.020044    32.768265    36.875282
# Argentina                          479.937460   522.441503   561.398445
# Armenia                           1538.655752  1487.814908  1527.937457
# Aruba                               56.140485    36.920295    34.264018
#
#                                          2020         2021         2022  \
# Remittance inflows (US$ million)
# Afghanistan                        788.917115   320.000000   370.000000
# Albania                           1465.987212  1718.355918  1745.245136
# Algeria                           1699.608935  1792.158957  1658.975810
# American Samoa                            NaN          NaN          NaN
# Andorra                             47.416324    53.001418     0.000000
# Angola                               8.053051    12.631149    14.005491
# Antigua and Barbuda                 36.220491    45.265850    47.183398
# Argentina                          648.090050   901.123183  1267.449071
# Armenia                           1327.006085  1556.822544  2034.814437
# Aruba                               34.984040    35.845637    38.279493
#
#                                         2023e  % of GDP in 2023
# Remittance inflows (US$ million)
# Afghanistan                        300.000000          2.007898
# Albania                           1970.000000          8.553317
# Algeria                           1770.000000          0.790179
# American Samoa                            NaN               NaN
# Andorra                              0.000000          0.000000
# Angola                              14.688758          0.015660
# Antigua and Barbuda                 49.448219          2.537107
# Argentina                         1600.000000          0.257235
# Armenia                           1850.000000          7.538712
# Aruba                               34.449858          0.900179
#
# [10 rows x 25 columns]

# %%
# Display the dataset information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 226 entries, Afghanistan to When using the data, please cite: World Bank-KNOMAD, December 2023
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   2000              199 non-null    float64
#  1   2001              199 non-null    float64
#  2   2002              199 non-null    float64
#  3   2003              199 non-null    float64
#  4   2004              199 non-null    float64
#  5   2005              199 non-null    float64
#  6   2006              199 non-null    float64
#  7   2007              198 non-null    float64
#  8   2008              198 non-null    float64
#  9   2009              198 non-null    float64
#  10  2010              198 non-null    float64
#  11  2011              197 non-null    float64
#  12  2012              197 non-null    float64
#  13  2013              197 non-null    float64
#  14  2014              197 non-null    float64
#  15  2015              197 non-null    float64
#  16  2016              197 non-null    float64
#  17  2017              196 non-null    float64
#  18  2018              196 non-null    float64
#  19  2019              196 non-null    float64
#  20  2020              196 non-null    float64
#  21  2021              196 non-null    float64
#  22  2022              196 non-null    float64
#  23  2023e             196 non-null    float64
#  24  % of GDP in 2023  190 non-null    float64
# dtypes: float64(25)
# memory usage: 45.9+ KB

# %%
# replace empty rows with NaN values
df.replace('', np.nan, inplace=True)

# %%
# Check for missing values
df.isna().sum()
# Out:
# 2000                27
# 2001                27
# 2002                27
# 2003                27
# 2004                27
# 2005                27
# 2006                27
# 2007                28
# 2008                28
# 2009                28
# 2010                28
# 2011                29
# 2012                29
# 2013                29
# 2014                29
# 2015                29
# 2016                29
# 2017                30
# 2018                30
# 2019                30
# 2020                30
# 2021                30
# 2022                30
# 2023e               30
# % of GDP in 2023    36
# dtype: int64

# %% [markdown]
# ### Preprocessing the data

# %%
# Selecting country names only
df = df.iloc[:214, :]

# Remove all rows that have missing values
df.dropna(inplace=True)
df
# Out:
# <ipython-input-6-80e5603f42c7>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)
#                                             2000         2001         2002  \
# Remittance inflows (US$ million)
# Afghanistan                                  0.0     0.000000     0.000000
# Albania                                    597.8   699.300000   733.570000
# Algeria                                      0.0     0.000000     0.000000
# Andorra                                      0.0     0.000000     0.000000
# Angola                                       0.0     0.000000     0.000000
# ...                                          ...          ...          ...
# Vietnam                                   1585.0  1100.000000  1767.000000
# West Bank and Gaza                         863.8   805.742463   771.775118
# Yemen, Rep.                                  0.0     0.000000     0.000000
# Zambia                                       0.0     0.000000     0.000000
# Zimbabwe (using CB data for 2021 & 2022)     0.0     0.000000     0.000000
#
#                                                  2003         2004  \
# Remittance inflows (US$ million)
# Afghanistan                                  0.000000     0.000000
# Albania                                    888.748582  1160.672105
# Algeria                                      0.000000     0.000000
# Andorra                                      0.000000     0.000000
# Angola                                       0.000000     0.000000
# ...                                               ...          ...
# Vietnam                                   2100.000000  2919.000000
# West Bank and Gaza                         310.077968   398.558393
# Yemen, Rep.                                  0.000000     0.000000
# Zambia                                      36.300000    48.400000
# Zimbabwe (using CB data for 2021 & 2022)     0.000000     0.000000
#
#                                                  2005         2006  \
# Remittance inflows (US$ million)
# Afghanistan                                  0.000000     0.000000
# Albania                                   1289.704316  1359.467325
# Algeria                                    170.000000   189.000000
# Andorra                                      0.000000     0.000000
# Angola                                       0.000000     0.000000
# ...                                               ...          ...
# Vietnam                                   3150.000000  3800.000000
# West Bank and Gaza                         378.337239   464.056318
# Yemen, Rep.                               1282.599000  1282.600000
# Zambia                                      52.900000    57.680000
# Zimbabwe (using CB data for 2021 & 2022)     0.000000     0.000000
#
#                                                  2007         2008  \
# Remittance inflows (US$ million)
# Afghanistan                                  0.000000    89.500000
# Albania                                   1468.020000  1865.600000
# Algeria                                     99.004563   103.631887
# Andorra                                      0.000000     0.000000
# Angola                                       0.000000    82.084000
# ...                                               ...          ...
# Vietnam                                   6180.000000  6804.000000
# West Bank and Gaza                         598.543423   740.724366
# Yemen, Rep.                               1321.520000  1410.520000
# Zambia                                      59.300000    68.195000
# Zimbabwe (using CB data for 2021 & 2022)     0.000000     0.000000
#
#                                                  2009  ...         2015  \
# Remittance inflows (US$ million)                       ...
# Afghanistan                                140.695166  ...   348.624717
# Albania                                   1717.698012  ...  1290.863508
# Algeria                                    150.336961  ...  1997.393458
# Andorra                                      0.000000  ...     0.000000
# Angola                                       0.200000  ...    11.114712
# ...                                               ...  ...          ...
# Vietnam                                   6018.000000  ...  8050.696859
# West Bank and Gaza                         755.235908  ...  1817.412109
# Yemen, Rep.                               1160.000000  ...  3350.500000
# Zambia                                      41.264000  ...    47.046538
# Zimbabwe (using CB data for 2021 & 2022)  1205.700000  ...  2046.579806
#
#                                                  2016         2017  \
# Remittance inflows (US$ million)
# Afghanistan                                627.710802   822.731630
# Albania                                   1306.009167  1311.822432
# Algeria                                   1989.023597  1791.887073
# Andorra                                      0.000000     0.000000
# Angola                                       3.988048     1.418196
# ...                                               ...          ...
# Vietnam                                   8556.092341  9405.606825
# West Bank and Gaza                        2086.576176  2378.923437
# Yemen, Rep.                               3770.584000  3770.584000
# Zambia                                      38.464441    93.644095
# Zimbabwe (using CB data for 2021 & 2022)  1856.034931  1729.883817
#
#                                                   2018          2019  \
# Remittance inflows (US$ million)
# Afghanistan                                 803.546454    828.571904
# Albania                                    1458.210056   1472.812242
# Algeria                                    1984.998399   1785.838683
# Andorra                                       0.000000     21.100000
# Angola                                        1.579247      3.445473
# ...                                                ...           ...
# Vietnam                                   10191.360839  10885.224766
# West Bank and Gaza                         2833.912788   3152.859814
# Yemen, Rep.                                3770.584000   3770.584000
# Zambia                                      106.965626     98.259121
# Zimbabwe (using CB data for 2021 & 2022)   1427.703019   1417.011953
#
#                                                   2020          2021  \
# Remittance inflows (US$ million)
# Afghanistan                                 788.917115    320.000000
# Albania                                    1465.987212   1718.355918
# Algeria                                    1699.608935   1792.158957
# Andorra                                      47.416324     53.001418
# Angola                                        8.053051     12.631149
# ...                                                ...           ...
# Vietnam                                   10714.571746  12722.088864
# West Bank and Gaza                         2559.660846   3760.462368
# Yemen, Rep.                                3770.584000   3770.584000
# Zambia                                      134.864832    239.709361
# Zimbabwe (using CB data for 2021 & 2022)   1832.039381   2573.626886
#
#                                                   2022         2023e  \
# Remittance inflows (US$ million)
# Afghanistan                                 370.000000    300.000000
# Albania                                    1745.245136   1970.000000
# Algeria                                    1658.975810   1770.000000
# Andorra                                       0.000000      0.000000
# Angola                                       14.005491     14.688758
# ...                                                ...           ...
# Vietnam                                   13200.000000  14000.000000
# West Bank and Gaza                         4049.078713   3800.000000
# Yemen, Rep.                                3770.584000   3770.584000
# Zambia                                      243.486023    250.000000
# Zimbabwe (using CB data for 2021 & 2022)   3085.043421   3115.893855
#
#                                           % of GDP in 2023
# Remittance inflows (US$ million)
# Afghanistan                                       2.007898
# Albania                                           8.553317
# Algeria                                           0.790179
# Andorra                                           0.000000
# Angola                                            0.015660
# ...                                                    ...
# Vietnam                                           3.233256
# West Bank and Gaza                               19.882900
# Yemen, Rep.                                      17.916769
# Zambia                                            0.846425
# Zimbabwe (using CB data for 2021 & 2022)          9.609838
#
# [186 rows x 25 columns]

# %%
# Save the merged file to csv
df.to_csv('remittance_inflows_clean.csv', index=True)

# %% [markdown]
# ##  Data Cleaning for Remittance Outflow

# %%
# Filepath
outflow_filepath = '/content/outward-remittance-flows-brief-39-december-2023-revised-as-of-mar.8-2024_1.xlsx'
outflow = pd.read_excel(outflow_filepath, index_col=0)
print(outflow.shape)
# Display the first few rows of the dataset
outflow.head(10)
outflow
# Out:
# (223, 24)
#                                                     2000  2001  2002  \
# Remittance outflows (US$ million)
# Afghanistan                                          0.0   0.0   0.0
# Albania                                              0.0   0.0   0.0
# Algeria                                              0.0   0.0   0.0
# American Samoa                                       NaN   NaN   NaN
# Andorra                                              0.0   0.0   0.0
# ...                                                  ...   ...   ...
# For additional information, please also see "In...   NaN   NaN   NaN
# GDP data from IMF World Economic Outlook             NaN   NaN   NaN
# For latest data and analysis on migration and r...   NaN   NaN   NaN
# Date: December 2023                                  NaN   NaN   NaN
# When using the data, please cite: KNOMAD/World ...   NaN   NaN   NaN
#
#                                                         2003     2004  \
# Remittance outflows (US$ million)
# Afghanistan                                         0.000000  0.00000
# Albania                                             4.135728  4.86374
# Algeria                                             0.000000  0.00000
# American Samoa                                           NaN      NaN
# Andorra                                             0.000000  0.00000
# ...                                                      ...      ...
# For additional information, please also see "In...       NaN      NaN
# GDP data from IMF World Economic Outlook                 NaN      NaN
# For latest data and analysis on migration and r...       NaN      NaN
# Date: December 2023                                      NaN      NaN
# When using the data, please cite: KNOMAD/World ...       NaN      NaN
#
#                                                          2005       2006  \
# Remittance outflows (US$ million)
# Afghanistan                                          0.000000   0.000000
# Albania                                              6.511798  26.532132
# Algeria                                             27.000000  35.000000
# American Samoa                                            NaN        NaN
# Andorra                                              0.000000   0.000000
# ...                                                       ...        ...
# For additional information, please also see "In...        NaN        NaN
# GDP data from IMF World Economic Outlook                  NaN        NaN
# For latest data and analysis on migration and r...        NaN        NaN
# Date: December 2023                                       NaN        NaN
# When using the data, please cite: KNOMAD/World ...        NaN        NaN
#
#                                                          2007        2008  \
# Remittance outflows (US$ million)
# Afghanistan                                          0.000000  216.600000
# Albania                                              9.940000  279.700000
# Algeria                                             48.863733   26.782545
# American Samoa                                            NaN         NaN
# Andorra                                              0.000000    0.000000
# ...                                                       ...         ...
# For additional information, please also see "In...        NaN         NaN
# GDP data from IMF World Economic Outlook                  NaN         NaN
# For latest data and analysis on migration and r...        NaN         NaN
# Date: December 2023                                       NaN         NaN
# When using the data, please cite: KNOMAD/World ...        NaN         NaN
#
#                                                           2009  ...  \
# Remittance outflows (US$ million)                               ...
# Afghanistan                                         624.996677  ...
# Albania                                             229.819782  ...
# Algeria                                              45.702406  ...
# American Samoa                                             NaN  ...
# Andorra                                               0.000000  ...
# ...                                                        ...  ...
# For additional information, please also see "In...         NaN  ...
# GDP data from IMF World Economic Outlook                   NaN  ...
# For latest data and analysis on migration and r...         NaN  ...
# Date: December 2023                                        NaN  ...
# When using the data, please cite: KNOMAD/World ...         NaN  ...
#
#                                                           2014        2015  \
# Remittance outflows (US$ million)
# Afghanistan                                         524.163479  228.991809
# Albania                                             178.722842  153.312400
# Algeria                                             295.922112   72.128991
# American Samoa                                             NaN         NaN
# Andorra                                               0.000000    0.000000
# ...                                                        ...         ...
# For additional information, please also see "In...         NaN         NaN
# GDP data from IMF World Economic Outlook                   NaN         NaN
# For latest data and analysis on migration and r...         NaN         NaN
# Date: December 2023                                        NaN         NaN
# When using the data, please cite: KNOMAD/World ...         NaN         NaN
#
#                                                           2016        2017  \
# Remittance outflows (US$ million)
# Afghanistan                                         167.894464  143.979106
# Albania                                             147.156757  106.330983
# Algeria                                              76.633496  214.378057
# American Samoa                                             NaN         NaN
# Andorra                                               0.000000    0.000000
# ...                                                        ...         ...
# For additional information, please also see "In...         NaN         NaN
# GDP data from IMF World Economic Outlook                   NaN         NaN
# For latest data and analysis on migration and r...         NaN         NaN
# Date: December 2023                                        NaN         NaN
# When using the data, please cite: KNOMAD/World ...         NaN         NaN
#
#                                                           2018        2019  \
# Remittance outflows (US$ million)
# Afghanistan                                         234.618701  217.292318
# Albania                                             114.879337  119.679641
# Algeria                                              87.006383   81.545365
# American Samoa                                             NaN         NaN
# Andorra                                               0.000000   91.500000
# ...                                                        ...         ...
# For additional information, please also see "In...         NaN         NaN
# GDP data from IMF World Economic Outlook                   NaN         NaN
# For latest data and analysis on migration and r...         NaN         NaN
# Date: December 2023                                        NaN         NaN
# When using the data, please cite: KNOMAD/World ...         NaN         NaN
#
#                                                           2020        2021  \
# Remittance outflows (US$ million)
# Afghanistan                                         225.420606    0.000000
# Albania                                             124.630376  140.344310
# Algeria                                             149.253465   83.259319
# American Samoa                                             NaN         NaN
# Andorra                                              83.804275   70.514091
# ...                                                        ...         ...
# For additional information, please also see "In...         NaN         NaN
# GDP data from IMF World Economic Outlook                   NaN         NaN
# For latest data and analysis on migration and r...         NaN         NaN
# Date: December 2023                                        NaN         NaN
# When using the data, please cite: KNOMAD/World ...         NaN         NaN
#
#                                                           2022  \
# Remittance outflows (US$ million)
# Afghanistan                                           0.000000
# Albania                                             149.489653
# Algeria                                              60.221598
# American Samoa                                             NaN
# Andorra                                               0.000000
# ...                                                        ...
# For additional information, please also see "In...         NaN
# GDP data from IMF World Economic Outlook                   NaN
# For latest data and analysis on migration and r...         NaN
# Date: December 2023                                        NaN
# When using the data, please cite: KNOMAD/World ...         NaN
#
#                                                     % of GDP in 2022
# Remittance outflows (US$ million)
# Afghanistan                                                      NaN
# Albania                                                     0.783366
# Algeria                                                     0.030873
# American Samoa                                                   NaN
# Andorra                                                          NaN
# ...                                                              ...
# For additional information, please also see "In...               NaN
# GDP data from IMF World Economic Outlook                         NaN
# For latest data and analysis on migration and r...               NaN
# Date: December 2023                                              NaN
# When using the data, please cite: KNOMAD/World ...               NaN
#
# [223 rows x 24 columns]

# %%
# Rename some outflow columns
#outflow = outflow.rename(columns={'% of GDP in 2021': '%GDP_2021'})
# Selecting country names only
outflow = outflow.iloc[:214, :]
outflow
# Out:
#                                    2000       2001       2002       2003  \
# Remittance outflows (US$ million)
# Afghanistan                         0.0   0.000000   0.000000   0.000000
# Albania                             0.0   0.000000   0.000000   4.135728
# Algeria                             0.0   0.000000   0.000000   0.000000
# American Samoa                      NaN        NaN        NaN        NaN
# Andorra                             0.0   0.000000   0.000000   0.000000
# ...                                 ...        ...        ...        ...
# Virgin Islands (U.S.)               NaN        NaN        NaN        NaN
# West Bank and Gaza                  5.6   4.900869   5.095333  17.883733
# Yemen, Rep.                         0.0   0.000000   0.000000   0.000000
# Zambia                             24.1  28.400000  37.500000  71.500000
# Zimbabwe                            0.0   0.000000   0.000000   0.000000
#
#                                         2004        2005        2006  \
# Remittance outflows (US$ million)
# Afghanistan                         0.000000    0.000000    0.000000
# Albania                             4.863740    6.511798   26.532132
# Algeria                             0.000000   27.000000   35.000000
# American Samoa                           NaN         NaN         NaN
# Andorra                             0.000000    0.000000    0.000000
# ...                                      ...         ...         ...
# Virgin Islands (U.S.)                    NaN         NaN         NaN
# West Bank and Gaza                 10.760551    6.475643    6.788488
# Yemen, Rep.                         0.000000  109.495910  120.440000
# Zambia                             76.100000   93.700000  115.457000
# Zimbabwe                            0.000000    0.000000    0.000000
#
#                                          2007        2008        2009  ...  \
# Remittance outflows (US$ million)                                      ...
# Afghanistan                          0.000000  216.600000  624.996677  ...
# Albania                              9.940000  279.700000  229.819782  ...
# Algeria                             48.863733   26.782545   45.702406  ...
# American Samoa                            NaN         NaN         NaN  ...
# Andorra                              0.000000    0.000000    0.000000  ...
# ...                                       ...         ...         ...  ...
# Virgin Islands (U.S.)                     NaN         NaN         NaN  ...
# West Bank and Gaza                   7.929239    8.299895    7.912044  ...
# Yemen, Rep.                        318.720000  336.840000  336.840000  ...
# Zambia                             123.930000  138.885000   65.617000  ...
# Zimbabwe                             0.000000    0.000000    8.600000  ...
#
#                                          2014        2015        2016  \
# Remittance outflows (US$ million)
# Afghanistan                        524.163479  228.991809  167.894464
# Albania                            178.722842  153.312400  147.156757
# Algeria                            295.922112   72.128991   76.633496
# American Samoa                            NaN         NaN         NaN
# Andorra                              0.000000    0.000000    0.000000
# ...                                       ...         ...         ...
# Virgin Islands (U.S.)                     NaN         NaN         NaN
# West Bank and Gaza                  36.128914   30.398350   30.393004
# Yemen, Rep.                        335.395533  333.389518  332.700000
# Zambia                              81.199881   72.104699   63.405836
# Zimbabwe                            10.840916   11.350439   13.844871
#
#                                          2017        2018        2019  \
# Remittance outflows (US$ million)
# Afghanistan                        143.979106  234.618701  217.292318
# Albania                            106.330983  114.879337  119.679641
# Algeria                            214.378057   87.006383   81.545365
# American Samoa                            NaN         NaN         NaN
# Andorra                              0.000000    0.000000   91.500000
# ...                                       ...         ...         ...
# Virgin Islands (U.S.)                     NaN         NaN         NaN
# West Bank and Gaza                  27.462198   22.347335   29.079904
# Yemen, Rep.                          0.000000    0.000000    0.000000
# Zambia                             121.370621  132.001364  103.806724
# Zimbabwe                            18.575000   29.278892   13.480566
#
#                                          2020        2021        2022  \
# Remittance outflows (US$ million)
# Afghanistan                        225.420606    0.000000    0.000000
# Albania                            124.630376  140.344310  149.489653
# Algeria                            149.253465   83.259319   60.221598
# American Samoa                            NaN         NaN         NaN
# Andorra                             83.804275   70.514091    0.000000
# ...                                       ...         ...         ...
# Virgin Islands (U.S.)                     NaN         NaN         NaN
# West Bank and Gaza                  21.881177   32.247854    9.330391
# Yemen, Rep.                          0.000000    0.000000    0.000000
# Zambia                              88.510886  122.331952  131.254123
# Zimbabwe                            21.707094    0.000000    0.000000
#
#                                    % of GDP in 2022
# Remittance outflows (US$ million)
# Afghanistan                                     NaN
# Albania                                    0.783366
# Algeria                                    0.030873
# American Samoa                                  NaN
# Andorra                                         NaN
# ...                                             ...
# Virgin Islands (U.S.)                           NaN
# West Bank and Gaza                         0.051524
# Yemen, Rep.                                     NaN
# Zambia                                     0.441309
# Zimbabwe                                        NaN
#
# [214 rows x 24 columns]

# %%
# Display the dataset information
outflow.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 214 entries, Afghanistan to Zimbabwe
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   2000              201 non-null    float64
#  1   2001              201 non-null    float64
#  2   2002              201 non-null    float64
#  3   2003              201 non-null    float64
#  4   2004              201 non-null    float64
#  5   2005              201 non-null    float64
#  6   2006              201 non-null    float64
#  7   2007              201 non-null    float64
#  8   2008              201 non-null    float64
#  9   2009              201 non-null    float64
#  10  2010              201 non-null    float64
#  11  2011              201 non-null    float64
#  12  2012              201 non-null    float64
#  13  2013              201 non-null    float64
#  14  2014              201 non-null    float64
#  15  2015              201 non-null    float64
#  16  2016              201 non-null    float64
#  17  2017              201 non-null    float64
#  18  2018              201 non-null    float64
#  19  2019              201 non-null    float64
#  20  2020              201 non-null    float64
#  21  2021              201 non-null    float64
#  22  2022              201 non-null    float64
#  23  % of GDP in 2022  158 non-null    float64
# dtypes: float64(24)
# memory usage: 41.8+ KB

# %%
# replace empty rows with NaN values
outflow.replace('', np.nan, inplace=True)
# Out:
# <ipython-input-22-df3aa2e83d9c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outflow.replace('', np.nan, inplace=True)

# %%
# Check for missing values
outflow.isnull().sum()
# Out:
# 2000                13
# 2001                13
# 2002                13
# 2003                13
# 2004                13
# 2005                13
# 2006                13
# 2007                13
# 2008                13
# 2009                13
# 2010                13
# 2011                13
# 2012                13
# 2013                13
# 2014                13
# 2015                13
# 2016                13
# 2017                13
# 2018                13
# 2019                13
# 2020                13
# 2021                13
# 2022                13
# % of GDP in 2022    56
# dtype: int64

# %%
# Remove all rows that have missing values
outflow.dropna(inplace=True)
outflow.head()
# Out:
# <ipython-input-24-0b571c6fadbc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outflow.dropna(inplace=True)
#                                          2000        2001        2002  \
# Remittance outflows (US$ million)
# Albania                              0.000000    0.000000    0.000000
# Algeria                              0.000000    0.000000    0.000000
# Angola                             266.290000  216.060000  223.507959
# Antigua and Barbuda                  1.558148    1.564444    1.411481
# Argentina                          267.700000  256.100000  119.550000
#
#                                          2003        2004        2005  \
# Remittance outflows (US$ million)
# Albania                              4.135728    4.863740    6.511798
# Algeria                              0.000000    0.000000   27.000000
# Angola                             229.849970  296.009591  214.905216
# Antigua and Barbuda                  1.489293    1.566737    1.670141
# Argentina                          180.410000  234.470000  314.010000
#
#                                          2006        2007        2008  \
# Remittance outflows (US$ million)
# Albania                             26.532132    9.940000  279.700000
# Algeria                             35.000000   48.863733   26.782545
# Angola                             412.666785  602.671451  669.453676
# Antigua and Barbuda                  1.837155    2.131100    2.367652
# Argentina                          356.500000  463.192097  631.436069
#
#                                          2009  ...         2014         2015  \
# Remittance outflows (US$ million)              ...
# Albania                            229.819782  ...   178.722842   153.312400
# Algeria                             45.702406  ...   295.922112    72.128991
# Angola                             716.000000  ...  2746.615873  1252.909012
# Antigua and Barbuda                  2.122363  ...    52.100000    52.822644
# Argentina                          766.571548  ...   732.414557   685.001366
#
#                                           2016         2017         2018  \
# Remittance outflows (US$ million)
# Albania                             147.156757   106.330983   114.879337
# Algeria                              76.633496   214.378057    87.006383
# Angola                             1176.110314   961.415276   681.627015
# Antigua and Barbuda                  54.742927    55.445390    54.174268
# Argentina                           769.242058  1060.484530  1010.375536
#
#                                          2019        2020        2021  \
# Remittance outflows (US$ million)
# Albania                            119.679641  124.630376  140.344310
# Algeria                             81.545365  149.253465   83.259319
# Angola                             549.082043  576.471437  445.400144
# Antigua and Barbuda                 47.772733   44.608057   52.574952
# Argentina                          669.932291  521.040572  596.899083
#
#                                          2022  % of GDP in 2022
# Remittance outflows (US$ million)
# Albania                            149.489653          0.783366
# Algeria                             60.221598          0.030873
# Angola                             517.668187          0.421619
# Antigua and Barbuda                 59.787266          3.400868
# Argentina                          590.412343          0.093626
#
# [5 rows x 24 columns]

# %%
outflow.shape
# Out:
# (158, 24)

# %%
outflow.dtypes
# Out:
# 2000                float64
# 2001                float64
# 2002                float64
# 2003                float64
# 2004                float64
# 2005                float64
# 2006                float64
# 2007                float64
# 2008                float64
# 2009                float64
# 2010                float64
# 2011                float64
# 2012                float64
# 2013                float64
# 2014                float64
# 2015                float64
# 2016                float64
# 2017                float64
# 2018                float64
# 2019                float64
# 2020                float64
# 2021                float64
# 2022                float64
# % of GDP in 2022    float64
# dtype: object

# %%
# Save cleaned remittance outflow data to CSV file
outflow.to_csv('remittance_outflows_clean.csv', index=True)
